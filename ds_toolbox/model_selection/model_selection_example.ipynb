# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, SGDClassifier, LinearRegression
from sklearn import datasets
from model_selection import ClfSwitcher, RegSwitcher
import pandas as pd

# %%
# Increase the number of rows to show in notebook
pd.set_option("display.max_rows", 2000)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
iris = datasets.load_iris()

# %% [markdown]
# ### Without pipeline

# %% [markdown]
# #### Classification

# %%
parameters = [
    {
        'estimator': [RandomForestClassifier()],
        'estimator__n_estimators':[150, 200], 
        'estimator__max_depth':[2, 3]
    },
    {
        'estimator':[SGDClassifier()],
        'estimator__alpha': (1e-2, 1e-3, 1e-1)
    }
]

# %%
gs = GridSearchCV(ClfSwitcher(), parameters, cv=3, n_jobs=3, verbose = 10)
gs.fit(iris.data, iris.target)
# Out:
# Fitting 3 folds for each of 7 candidates, totalling 21 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=3)]: Done  19 out of  21 | elapsed:    1.8s remaining:    0.1s
# [Parallel(n_jobs=3)]: Done  21 out of  21 | elapsed:    1.8s finished
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=ClfSwitcher(estimator=RandomForestClassifier(bootstrap=True,
#                                                                     class_weight=None,
#                                                                     criterion='gini',
#                                                                     max_depth=None,
#                                                                     max_features='auto',
#                                                                     max_leaf_nodes=None,
#                                                                     min_impurity_decrease=0.0,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=1,
#                                                                     min_samples_split=2,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators='warn',
#                                                                     n_...
#                                                       fit_intercept=True,
#                                                       l1_ratio=0.15,
#                                                       learning_rate='optimal',
#                                                       loss='hinge',
#                                                       max_iter=1000,
#                                                       n_iter_no_change=5,
#                                                       n_jobs=None, penalty='l2',
#                                                       power_t=0.5,
#                                                       random_state=None,
#                                                       shuffle=True, tol=0.001,
#                                                       validation_fraction=0.1,
#                                                       verbose=0,
#                                                       warm_start=False)],
#                           'estimator__alpha': (0.01, 0.001, 0.1)}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
cv_res = pd.DataFrame(gs.cv_results_)

# %%
cv_res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.0957        0.0064           0.0156          0.0000
# 1         0.1497        0.0154           0.0128          0.0038
# 2         0.0938        0.0038           0.0101          0.0075
# 3         0.1386        0.0127           0.0138          0.0051
# 4         0.0027        0.0038           0.0007          0.0010
# 5         0.0007        0.0010           0.0034          0.0048
# 6         0.0027        0.0038           0.0000          0.0000
#
#                                      param_estimator  \
# 0  (DecisionTreeClassifier(class_weight=None, cri...
# 1  (DecisionTreeClassifier(class_weight=None, cri...
# 2  (DecisionTreeClassifier(class_weight=None, cri...
# 3  (DecisionTreeClassifier(class_weight=None, cri...
# 4  SGDClassifier(alpha=0.0001, average=False, cla...
# 5  SGDClassifier(alpha=0.0001, average=False, cla...
# 6  SGDClassifier(alpha=0.0001, average=False, cla...
#
#   param_estimator__max_depth param_estimator__n_estimators  \
# 0                          2                           150
# 1                          2                           200
# 2                          3                           150
# 3                          3                           200
# 4                        NaN                           NaN
# 5                        NaN                           NaN
# 6                        NaN                           NaN
#
#   param_estimator__alpha                                             params  \
# 0                    NaN  {'estimator': (DecisionTreeClassifier(class_we...
# 1                    NaN  {'estimator': (DecisionTreeClassifier(class_we...
# 2                    NaN  {'estimator': (DecisionTreeClassifier(class_we...
# 3                    NaN  {'estimator': (DecisionTreeClassifier(class_we...
# 4                 0.0100  {'estimator': SGDClassifier(alpha=0.0001, aver...
# 5                 0.0010  {'estimator': SGDClassifier(alpha=0.0001, aver...
# 6                 0.1000  {'estimator': SGDClassifier(alpha=0.0001, aver...
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0             0.9608             0.9412             0.9792           0.9600
# 1             0.9608             0.9412             0.9792           0.9600
# 2             0.9804             0.9216             0.9792           0.9600
# 3             0.9804             0.9216             0.9792           0.9600
# 4             0.9216             0.8824             0.7083           0.8400
# 5             0.7059             0.6863             0.9583           0.7800
# 6             0.8627             0.7451             1.0000           0.8667
#
#    std_test_score  rank_test_score
# 0          0.0154                1
# 1          0.0154                1
# 2          0.0276                1
# 3          0.0276                1
# 4          0.0918                6
# 5          0.1226                7
# 6          0.1035                5

# %% [markdown]
# #### Regression

# %%
parameters = [
    {
        'estimator': [RandomForestRegressor()],
        'estimator__n_estimators':[150, 200], 
        'estimator__max_depth':[2, 3]
    },
    {
        'estimator':[LinearRegression()],
        'estimator__fit_intercept': [True, False]
    }
]

# %%
gs = GridSearchCV(RegSwitcher(), parameters, cv=3, n_jobs=3, verbose=10, scoring='neg_mean_squared_error')
gs.fit(iris.data, iris.target)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Batch computation too fast (0.0859s.) Setting batch_size=4.
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done   5 out of  18 | elapsed:    0.1s remaining:    0.5s
# [Parallel(n_jobs=3)]: Done  18 out of  18 | elapsed:    0.5s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RegSwitcher(estimator=RandomForestRegressor(bootstrap=True,
#                                                                    criterion='mse',
#                                                                    max_depth=None,
#                                                                    max_features='auto',
#                                                                    max_leaf_nodes=None,
#                                                                    min_impurity_decrease=0.0,
#                                                                    min_impurity_split=None,
#                                                                    min_samples_leaf=1,
#                                                                    min_samples_split=2,
#                                                                    min_weight_fraction_leaf=0.0,
#                                                                    n_estimators='warn',
#                                                                    n_jobs=None,
#                                                                    oob_score=...
#                                                               random_state=None,
#                                                               verbose=0,
#                                                               warm_start=False)],
#                           'estimator__max_depth': [2, 3],
#                           'estimator__n_estimators': [150, 200]},
#                          {'estimator': [LinearRegression(copy_X=True,
#                                                          fit_intercept=False,
#                                                          n_jobs=None,
#                                                          normalize=False)],
#                           'estimator__fit_intercept': [True, False]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=10)

# %%
cv_res = pd.DataFrame(gs.cv_results_)

# %%
cv_res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.0631        0.0065           0.0105          0.0074
# 1         0.1352        0.0067           0.0137          0.0012
# 2         0.0794        0.0033           0.0069          0.0065
# 3         0.0997        0.0184           0.0020          0.0028
# 4         0.0020        0.0022           0.0007          0.0005
# 5         0.0003        0.0005           0.0003          0.0005
#
#                                      param_estimator  \
# 0  RandomForestRegressor(bootstrap=True, criterio...
# 1  RandomForestRegressor(bootstrap=True, criterio...
# 2  RandomForestRegressor(bootstrap=True, criterio...
# 3  RandomForestRegressor(bootstrap=True, criterio...
# 4  LinearRegression(copy_X=True, fit_intercept=Fa...
# 5  LinearRegression(copy_X=True, fit_intercept=Fa...
#
#   param_estimator__max_depth param_estimator__n_estimators  \
# 0                          2                           150
# 1                          2                           200
# 2                          3                           150
# 3                          3                           200
# 4                        NaN                           NaN
# 5                        NaN                           NaN
#
#   param_estimator__fit_intercept  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                           True
# 5                          False
#
#                                               params  split0_test_score  \
# 0  {'estimator': RandomForestRegressor(bootstrap=...            -1.0806
# 1  {'estimator': RandomForestRegressor(bootstrap=...            -1.0698
# 2  {'estimator': RandomForestRegressor(bootstrap=...            -1.0725
# 3  {'estimator': RandomForestRegressor(bootstrap=...            -1.1182
# 4  {'estimator': LinearRegression(copy_X=True, fi...            -0.5557
# 5  {'estimator': LinearRegression(copy_X=True, fi...            -0.4434
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            -0.8468            -1.0000          -0.9758          0.0970
# 1            -0.8350            -1.0000          -0.9683          0.0984
# 2            -0.8371            -1.0000          -0.9699          0.0985
# 3            -0.8301            -1.0000          -0.9827          0.1182
# 4            -0.1684            -0.3833          -0.3692          0.1584
# 5            -0.1488            -0.3730          -0.3217          0.1256
#
#    rank_test_score
# 0                5
# 1                3
# 2                4
# 3                6
# 4                2
# 5                1

# %%
model = RegSwitcher(RandomForestRegressor())
model.fit(iris.data, iris.target)
# Out:
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RegSwitcher(estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                             max_depth=None, max_features='auto',
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_impurity_split=None,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=10, n_jobs=None,
#                                             oob_score=False, random_state=None,
#                                             verbose=0, warm_start=False))

# %%
model.score(iris.data, iris.target)
# Out:
# 0.9889

# %% [markdown]
# ### With pipeline

# %%
parameters = [
    {
        'clf__estimator': [RandomForestClassifier()],
        'clf__estimator__n_estimators':[150, 200], 
        'clf__estimator__max_depth':[2, 3]
    },
    {
        'clf__estimator':[SGDClassifier()],
        'clf__estimator__alpha': (1e-2, 1e-3, 1e-1)
    }
]

# %%
pipeline = Pipeline([('clf', ClfSwitcher())])

# %%
gs = GridSearchCV(pipeline, parameters, cv=3, n_jobs=3)
gs.fit(iris.data, iris.target)
# Out:
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('clf',
#                                         ClfSwitcher(estimator=RandomForestClassifier(bootstrap=True,
#                                                                                      class_weight=None,
#                                                                                      criterion='gini',
#                                                                                      max_depth=None,
#                                                                                      max_features='auto',
#                                                                                      max_leaf_nodes=None,
#                                                                                      min_impurity_decrease=0.0,
#                                                                                      min_impurity_split=None,
#                                                                                      min_samples_leaf=1,
#                                                                                      min_samples_split=2,
#                                                                                      min_weight_fract...
#                                                            fit_intercept=True,
#                                                            l1_ratio=0.15,
#                                                            learning_rate='optimal',
#                                                            loss='hinge',
#                                                            max_iter=1000,
#                                                            n_iter_no_change=5,
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            power_t=0.5,
#                                                            random_state=None,
#                                                            shuffle=True,
#                                                            tol=0.001,
#                                                            validation_fraction=0.1,
#                                                            verbose=0,
#                                                            warm_start=False)],
#                           'clf__estimator__alpha': (0.01, 0.001, 0.1)}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
gs.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('clf',
#                  ClfSwitcher(estimator=RandomForestClassifier(bootstrap=True,
#                                                               class_weight=None,
#                                                               criterion='gini',
#                                                               max_depth=2,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               n_estimators=200,
#                                                               n_jobs=None,
#                                                               oob_score=False,
#                                                               random_state=None,
#                                                               verbose=0,
#                                                               warm_start=False)))],
#          verbose=False)

# %%
cv_res = pd.DataFrame(gs.cv_results_)

# %%
cv_res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.0853        0.0016           0.0157          0.0000
# 1         0.1211        0.0074           0.0104          0.0074
# 2         0.0919        0.0102           0.0138          0.0026
# 3         0.1254        0.0055           0.0093          0.0056
# 4         0.0000        0.0000           0.0000          0.0000
# 5         0.0000        0.0000           0.0000          0.0000
# 6         0.0027        0.0038           0.0000          0.0000
#
#                                 param_clf__estimator  \
# 0  (DecisionTreeClassifier(class_weight=None, cri...
# 1  (DecisionTreeClassifier(class_weight=None, cri...
# 2  (DecisionTreeClassifier(class_weight=None, cri...
# 3  (DecisionTreeClassifier(class_weight=None, cri...
# 4  SGDClassifier(alpha=0.0001, average=False, cla...
# 5  SGDClassifier(alpha=0.0001, average=False, cla...
# 6  SGDClassifier(alpha=0.0001, average=False, cla...
#
#   param_clf__estimator__max_depth param_clf__estimator__n_estimators  \
# 0                               2                                150
# 1                               2                                200
# 2                               3                                150
# 3                               3                                200
# 4                             NaN                                NaN
# 5                             NaN                                NaN
# 6                             NaN                                NaN
#
#   param_clf__estimator__alpha  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                      0.0100
# 5                      0.0010
# 6                      0.1000
#
#                                               params  split0_test_score  \
# 0  {'clf__estimator': (DecisionTreeClassifier(cla...             0.9608
# 1  {'clf__estimator': (DecisionTreeClassifier(cla...             0.9608
# 2  {'clf__estimator': (DecisionTreeClassifier(cla...             0.9804
# 3  {'clf__estimator': (DecisionTreeClassifier(cla...             0.9804
# 4  {'clf__estimator': SGDClassifier(alpha=0.0001,...             0.9412
# 5  {'clf__estimator': SGDClassifier(alpha=0.0001,...             0.7843
# 6  {'clf__estimator': SGDClassifier(alpha=0.0001,...             0.7451
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             0.9020             0.9792           0.9467          0.0329
# 1             0.9412             0.9792           0.9600          0.0154
# 2             0.9216             0.9792           0.9600          0.0276
# 3             0.9216             0.9792           0.9600          0.0276
# 4             0.7647             0.9167           0.8733          0.0786
# 5             0.7843             0.7917           0.7867          0.0034
# 6             0.6667             0.6667           0.6933          0.0372
#
#    rank_test_score
# 0                4
# 1                1
# 2                1
# 3                1
# 4                5
# 5                6
# 6                7

# %% [markdown]
# ### Testing with homemade feature selector

# %%
import os
import sys

# %%
# Set the root path of the project
PROJECT_ROOT_PATH = os.path.dirname(os.path.abspath(os.path.join(os.getcwd())))
sys.path.append(PROJECT_ROOT_PATH)
sys.path.append(f'{PROJECT_ROOT_PATH}\ds_toolbox')

# %%
from feature_selection.feat_selector import *

# %%
model_cols = iris['feature_names']

# %%
df = pd.DataFrame(data=np.c_[iris['data'], iris['target']], columns=model_cols + ['target'])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0             5.1000            3.5000             1.4000            0.2000
# 1             4.9000            3.0000             1.4000            0.2000
# 2             4.7000            3.2000             1.3000            0.2000
# 3             4.6000            3.1000             1.5000            0.2000
# 4             5.0000            3.6000             1.4000            0.2000
#
#    target
# 0  0.0000
# 1  0.0000
# 2  0.0000
# 3  0.0000
# 4  0.0000

# %%
test = df.sample(frac = 0.2, replace = False)
train = df[~df.index.isin(test.index)]

# %%
available_strategies=RegFeatureSelector()._available_strategies

# %%
for strategy in available_strategies:
    print('\nStrategy=',strategy)
    fs=RegFeatureSelector(strategy=strategy)
    X_adj=fs.fit_transform(train[model_cols], train['target'])
    selected_cols=list(X_adj.columns)
    print('selected_cols=',len(selected_cols),sorted(selected_cols))
# Out:
# Strategy= variance
# selected_cols= 3 ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)']
#
# Strategy= l1
# selected_cols= 0 []
#
# Strategy= rf_feature_importance
# selected_cols= 3 ['petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
#
# Strategy= rf_top_features
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# selected_cols= 4 ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)', 'sepal width (cm)']
#
# Strategy= stepwise
# selected_cols= 3 ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)']
# C:\Users\idfri\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# #### Connecting model selector and feature selector using pipelines

# %%
available_strategies
# Out:
# ['variance', 'l1', 'rf_feature_importance', 'rf_top_features', 'stepwise']

# %%
pipeline = Pipeline(
    [
        ('feature_selector', RegFeatureSelector()), 
        ('model', RegSwitcher())
    ]
)

# %%
parameters = [
    {
        'model__estimator': [RandomForestRegressor()],
        'model__estimator__n_estimators':[150, 200], 
        'model__estimator__max_depth':[2, 3],
        'feature_selector__strategy':['variance', 'rf_feature_importance', 'rf_top_features', 'stepwise']
    },
    {
        'model__estimator':[LinearRegression()],
        'model__estimator__fit_intercept': [True, False],
        'feature_selector__strategy':['variance', 'rf_feature_importance', 'rf_top_features', 'stepwise']
    }
]

# %%
gs = GridSearchCV(pipeline, parameters, cv=3, n_jobs=3, scoring='neg_mean_squared_error')
gs.fit(df[model_cols], df['target'])
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('feature_selector',
#                                         <feature_selection.feat_selector.RegFeatureSelector object at 0x000001DBCD80CC88>),
#                                        ('model',
#                                         RegSwitcher(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                     criterion='mse',
#                                                                                     max_depth=None,
#                                                                                     max_features='auto',
#                                                                                     max_leaf_nodes=None,
#                                                                                     min_impurity_decrease=0...
#                           'model__estimator__n_estimators': [150, 200]},
#                          {'feature_selector__strategy': ['variance',
#                                                          'rf_feature_importance',
#                                                          'rf_top_features',
#                                                          'stepwise'],
#                           'model__estimator': [LinearRegression(copy_X=True,
#                                                                 fit_intercept=False,
#                                                                 n_jobs=None,
#                                                                 normalize=False)],
#                           'model__estimator__fit_intercept': [True, False]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
gs.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('feature_selector',
#                  <feature_selection.feat_selector.RegFeatureSelector object at 0x000001DBCDE5C708>),
#                 ('model',
#                  RegSwitcher(estimator=LinearRegression(copy_X=True,
#                                                         fit_intercept=False,
#                                                         n_jobs=None,
#                                                         normalize=False)))],
#          verbose=False)

# %%
cv_res = pd.DataFrame(gs.cv_results_)

# %%
cv_res
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.0647        0.0031           0.0133          0.0100
# 1          0.0825        0.0010           0.0101          0.0001
# 2          0.0799        0.0074           0.0074          0.0038
# 3          0.1074        0.0044           0.0041          0.0044
# 4          0.3209        0.0211           0.0052          0.0074
# 5          0.3446        0.0135           0.0074          0.0064
# 6          0.3163        0.0128           0.0104          0.0074
# 7          0.3416        0.0093           0.0052          0.0074
# 8          0.3551        0.0105           0.0052          0.0074
# 9          0.4167        0.0128           0.0052          0.0074
# 10         0.3469        0.0224           0.0052          0.0074
# 11         0.3521        0.0131           0.0126          0.0043
# 12         0.1776        0.0064           0.0104          0.0074
# 13         0.1838        0.0252           0.0092          0.0056
# 14         0.1538        0.0118           0.0139          0.0047
# 15         0.3294        0.0112           0.0154          0.0038
# 16         0.0040        0.0043           0.0027          0.0038
# 17         0.0040        0.0044           0.0027          0.0038
# 18         0.2528        0.0059           0.0020          0.0000
# 19         0.2623        0.0018           0.0000          0.0000
# 20         0.3033        0.0089           0.0017          0.0012
# 21         0.3702        0.0103           0.0000          0.0000
# 22         0.0847        0.0000           0.0000          0.0000
# 23         0.0595        0.0135           0.0022          0.0031
#
#    param_feature_selector__strategy  \
# 0                          variance
# 1                          variance
# 2                          variance
# 3                          variance
# 4             rf_feature_importance
# 5             rf_feature_importance
# 6             rf_feature_importance
# 7             rf_feature_importance
# 8                   rf_top_features
# 9                   rf_top_features
# 10                  rf_top_features
# 11                  rf_top_features
# 12                         stepwise
# 13                         stepwise
# 14                         stepwise
# 15                         stepwise
# 16                         variance
# 17                         variance
# 18            rf_feature_importance
# 19            rf_feature_importance
# 20                  rf_top_features
# 21                  rf_top_features
# 22                         stepwise
# 23                         stepwise
#
#                                param_model__estimator  \
# 0   RandomForestRegressor(bootstrap=True, criterio...
# 1   RandomForestRegressor(bootstrap=True, criterio...
# 2   RandomForestRegressor(bootstrap=True, criterio...
# 3   RandomForestRegressor(bootstrap=True, criterio...
# 4   RandomForestRegressor(bootstrap=True, criterio...
# 5   RandomForestRegressor(bootstrap=True, criterio...
# 6   RandomForestRegressor(bootstrap=True, criterio...
# 7   RandomForestRegressor(bootstrap=True, criterio...
# 8   RandomForestRegressor(bootstrap=True, criterio...
# 9   RandomForestRegressor(bootstrap=True, criterio...
# 10  RandomForestRegressor(bootstrap=True, criterio...
# 11  RandomForestRegressor(bootstrap=True, criterio...
# 12  RandomForestRegressor(bootstrap=True, criterio...
# 13  RandomForestRegressor(bootstrap=True, criterio...
# 14  RandomForestRegressor(bootstrap=True, criterio...
# 15  RandomForestRegressor(bootstrap=True, criterio...
# 16  LinearRegression(copy_X=True, fit_intercept=Fa...
# 17  LinearRegression(copy_X=True, fit_intercept=Fa...
# 18  LinearRegression(copy_X=True, fit_intercept=Fa...
# 19  LinearRegression(copy_X=True, fit_intercept=Fa...
# 20  LinearRegression(copy_X=True, fit_intercept=Fa...
# 21  LinearRegression(copy_X=True, fit_intercept=Fa...
# 22  LinearRegression(copy_X=True, fit_intercept=Fa...
# 23  LinearRegression(copy_X=True, fit_intercept=Fa...
#
#    param_model__estimator__max_depth param_model__estimator__n_estimators  \
# 0                                  2                                  150
# 1                                  2                                  200
# 2                                  3                                  150
# 3                                  3                                  200
# 4                                  2                                  150
# 5                                  2                                  200
# 6                                  3                                  150
# 7                                  3                                  200
# 8                                  2                                  150
# 9                                  2                                  200
# 10                                 3                                  150
# 11                                 3                                  200
# 12                                 2                                  150
# 13                                 2                                  200
# 14                                 3                                  150
# 15                                 3                                  200
# 16                               NaN                                  NaN
# 17                               NaN                                  NaN
# 18                               NaN                                  NaN
# 19                               NaN                                  NaN
# 20                               NaN                                  NaN
# 21                               NaN                                  NaN
# 22                               NaN                                  NaN
# 23                               NaN                                  NaN
#
#    param_model__estimator__fit_intercept  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                  True
# 17                                 False
# 18                                  True
# 19                                 False
# 20                                  True
# 21                                 False
# 22                                  True
# 23                                 False
#
#                                                params  split0_test_score  \
# 0   {'feature_selector__strategy': 'variance', 'mo...            -1.0732
# 1   {'feature_selector__strategy': 'variance', 'mo...            -1.0627
# 2   {'feature_selector__strategy': 'variance', 'mo...            -1.0753
# 3   {'feature_selector__strategy': 'variance', 'mo...            -1.1084
# 4   {'feature_selector__strategy': 'rf_feature_imp...            -1.0098
# 5   {'feature_selector__strategy': 'rf_feature_imp...            -1.0116
# 6   {'feature_selector__strategy': 'rf_feature_imp...            -1.0020
# 7   {'feature_selector__strategy': 'rf_feature_imp...            -1.0032
# 8   {'feature_selector__strategy': 'rf_top_feature...            -1.0662
# 9   {'feature_selector__strategy': 'rf_top_feature...            -1.0483
# 10  {'feature_selector__strategy': 'rf_top_feature...            -1.1207
# 11  {'feature_selector__strategy': 'rf_top_feature...            -1.1010
# 12  {'feature_selector__strategy': 'stepwise', 'mo...            -1.0803
# 13  {'feature_selector__strategy': 'stepwise', 'mo...            -1.0668
# 14  {'feature_selector__strategy': 'stepwise', 'mo...            -1.0839
# 15  {'feature_selector__strategy': 'stepwise', 'mo...            -1.0867
# 16  {'feature_selector__strategy': 'variance', 'mo...            -0.1947
# 17  {'feature_selector__strategy': 'variance', 'mo...            -0.1974
# 18  {'feature_selector__strategy': 'rf_feature_imp...            -0.4328
# 19  {'feature_selector__strategy': 'rf_feature_imp...            -0.4045
# 20  {'feature_selector__strategy': 'rf_top_feature...            -0.5557
# 21  {'feature_selector__strategy': 'rf_top_feature...            -0.4434
# 22  {'feature_selector__strategy': 'stepwise', 'mo...            -0.5557
# 23  {'feature_selector__strategy': 'stepwise', 'mo...            -0.4434
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             -0.8330            -1.0000          -0.9687          0.1005
# 1             -0.8382            -1.0000          -0.9670          0.0946
# 2             -0.8437            -1.0000          -0.9730          0.0965
# 3             -0.8361            -1.0000          -0.9815          0.1119
# 4             -0.8267            -1.0000          -0.9455          0.0841
# 5             -0.8320            -1.0000          -0.9479          0.0821
# 6             -0.8368            -1.0000          -0.9463          0.0774
# 7             -0.8300            -1.0000          -0.9444          0.0809
# 8             -0.8300            -1.0000          -0.9654          0.0995
# 9             -0.8257            -1.0000          -0.9580          0.0956
# 10            -0.8504            -1.0000          -0.9903          0.1106
# 11            -0.8287            -1.0000          -0.9766          0.1124
# 12            -0.8424            -1.0000          -0.9742          0.0988
# 13            -0.8247            -1.0000          -0.9638          0.1021
# 14            -0.8419            -1.0000          -0.9753          0.1003
# 15            -0.8275            -1.0000          -0.9714          0.1077
# 16            -0.1569            -0.3444          -0.2320          0.0810
# 17            -0.1451            -0.3421          -0.2282          0.0833
# 18            -0.1569            -0.3273          -0.3057          0.1136
# 19            -0.1451            -0.2892          -0.2796          0.1061
# 20            -0.1684            -0.3833          -0.3692          0.1584
# 21            -0.1488            -0.3730          -0.3217          0.1256
# 22            -0.1569            -0.3849          -0.3658          0.1634
# 23            -0.1451            -0.3687          -0.3190          0.1268
#
#     rank_test_score
# 0                17
# 1                16
# 2                19
# 3                23
# 4                10
# 5                12
# 6                11
# 7                 9
# 8                15
# 9                13
# 10               24
# 11               22
# 12               20
# 13               14
# 14               21
# 15               18
# 16                2
# 17                1
# 18                4
# 19                3
# 20                8
# 21                6
# 22                7
# 23                5
